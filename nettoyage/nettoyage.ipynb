# %%
# !pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.1/13.1 MB 19.2 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 346.6/346.6 KB 17.2 MB/s eta 0:00:00
# ...

# %%
import pandas as pd


def drop_remuneration_et_promotions():
    col_to_drop  = ["Spatial perimeter", "Indicator", "Type of contract", "Employee category", "M3E classification", "Gender", "Unit"]
    df_remuneration = pd.read_csv("bilan-social-d-edf-sa-remuneration-et-promotions.csv", sep = ";")
    df = df_remuneration.drop(col_to_drop, axis = 1)
    
    return df

def drop_formation():
    col_to_drop_formation = ["Spatial perimeter", "Indicator", "Employee category", "M3E classification", "Gender", "Unit"]
    df_formation = pd.read_csv("bilan-social-d-edf-sa-formation.csv", sep = ";")
    df = df_formation.drop(col_to_drop_formation, axis = 1)
    
    return df
   

def drop_droit_du_travail():
    col_to_drop_droit  = ["Spatial perimeter", "Indicator", "Type of legal action", "Unit"]
    df_droit = pd.read_csv("bilan-social-d-edf-sa-droit-du-travail.csv", sep = ";")
    
    df = df_droit(col_to_drop_droit, axis = 1)
    
    return df
    

def drop_others_conditions():
    col_to_drop_others_conditions = ["Spatial perimeter", "Indicator", "Type of contract", "Time range","Employee category", "Gender", "Unit"]
    df_condition = pd.read_csv("bilan-social-d-edf-sa-autres-conditions-de-travail(1).csv", sep = ";")
    
    df = df_condition.drop(col_to_drop_others_conditions)
    return df
    
 # Test des fonctions   
df_remuneration_promotions = drop_remuneration_et_promotions()
df_remuneration_promotions

df_formations = drop_formation()
df_formations
# Out:
#      Année Perimètre juridique Perimètre spatial  \
# 0     2023              EDF SA            France
# 1     2023              EDF SA            France
# 2     2023              EDF SA            France
# 3     2023              EDF SA            France
# 4     2023              EDF SA            France
# ..     ...                 ...               ...
# 436   2017              EDF SA            France
# 437   2017              EDF SA            France
# 438   2017              EDF SA            France
# 439   2017              EDF SA            France
# 440   2017              EDF SA            France
#
#                                             Indicateur   Collège Plage M3E  \
# 0    Montant consacré à la formation continue - INT...       NaN       NaN
# 1    Montant consacré à la formation continue - AUTRES       NaN       NaN
# 2               Salariés ayant suivi au moins un stage  Maitrise       NaN
# ...
